# %% [markdown]
# ## Cricket Data Analysis
#
# #### To get data, go to - https://www.espncricinfo.com/records/highest-career-batting-average-282910
#
# - 1.Open Excel and go to Data tab.
# - 2.Select "From Web" and enter the URL.
# - 3.Import the table data, remove " - " and add duplicate entries and save the file as a CSV.

# %%
# Import Library

import pandas as pd

# %%
# Import data

df = pd.read_csv("CricketData.csv")
df
# Out:
#                Player       Span  Mat  Inns  NO  Runs    HS    Ave     BF  \
# 0    DG Bradman (AUS)  1928-1948   52    80  10  6996   334  99.94  9800+
# 1      HC Brook (ENG)  2022-2023   12    20   1  1181   186  62.15   1287
# 2      AC Voges (AUS)  2015-2016   20    31   7  1485  269*  61.87   2667
# 3     RG Pollock (SA)  1963-1970   23    41   4  2256   274  60.97  1707+
# 4     GA Headley (WI)  1930-1954   22    40   4  2190  270*  60.83   416+
# ..                ...        ...  ...   ...  ..   ...   ...    ...    ...
# 61   KD Walters (AUS)  1965-1981   74   125  14  5357   250  48.26  8662+
# 62  GC Smith (ICC/SA)  2002-2014  117   205  13  9265   277  48.25  15525
# 63  WH Ponsford (AUS)  1924-1934   29    48   4  2122   266  48.22  3118+
# 64    SJ McCabe (AUS)  1930-1938   39    62   5  2748   232  48.21  3217+
# 65   DR Jardine (ENG)  1928-1934   22    33   6  1296   127  48.00  2110+
#
#        SR  100  50   0    4s  6s
# 0   58.60   29  13   7  626+   6
# 1   91.76    4   7   1   141  23
# 2   55.68    5   4   2   186   5
# 3   54.48    7  11   1  246+  11
# 4   56.00   10   5   2  104+   1
# ..    ...  ...  ..  ..   ...  ..
# 61  49.16   15  33   4  525+  23
# 62  59.67   27  38  11  1165  24
# 63  44.77    7   6   1  119+   0
# 64  60.02    6  13   4  241+  5+
# 65  25.59    1  10   2   53+   0
#
# [66 rows x 15 columns]

# %%
# Renaming column names

df = df.rename(columns = {
    'Mat': 'matches_played', 
    'NO': 'not_outs', 
    'HS': 'highest_inns_score',
    'BF': 'balls_faced',
    'SR': 'strike_rate'
})

# %%
df.head()
# Out:
#              Player       Span  matches_played  Inns  not_outs  Runs  \
# 0  DG Bradman (AUS)  1928-1948              52    80        10  6996
# 1    HC Brook (ENG)  2022-2023              12    20         1  1181
# 2    AC Voges (AUS)  2015-2016              20    31         7  1485
# 3   RG Pollock (SA)  1963-1970              23    41         4  2256
# 4   GA Headley (WI)  1930-1954              22    40         4  2190
#
#   highest_inns_score    Ave balls_faced  strike_rate  100  50  0    4s  6s
# 0                334  99.94       9800+        58.60   29  13  7  626+   6
# 1                186  62.15        1287        91.76    4   7  1   141  23
# 2               269*  61.87        2667        55.68    5   4  2   186   5
# 3                274  60.97       1707+        54.48    7  11  1  246+  11
# 4               270*  60.83        416+        56.00   10   5  2  104+   1

# %%
# check null values

#df.isnull() - this will give true or false in the dataframe for nulls

df.isnull().any()  #this will give True/False if there is any null in the col
# Out:
# Player                False
# Span                  False
# matches_played        False
# Inns                  False
# not_outs              False
# Runs                  False
# highest_inns_score    False
# Ave                   False
# balls_faced            True
# strike_rate            True
# 100                   False
# 50                    False
# 0                     False
# 4s                    False
# 6s                    False
# dtype: bool

# %%
# get only rows with null values

df[df['balls_faced'].isna() == 1]
# Out:
#                   Player       Span  matches_played  Inns  not_outs  Runs  \
# 8         ED Weekes (WI)  1948-1958              48    81         5  4455
# 16       CL Walcott (WI)  1948-1960              44    74         7  3798
# 58  Hon.FS Jackson (ENG)  1893-1905              20    33         4  1415
#
#    highest_inns_score    Ave balls_faced  strike_rate  100  50  0    4s  6s
# 8                 207  58.61         NaN          NaN   15  19  6  258+   2
# 16                220  56.68         NaN          NaN   15  14  1  107+  11
# 58               144*  48.79         NaN          NaN    5   6  3   51+   0

# %%
# Replace null with 0

df['strike_rate'] = df['strike_rate'].fillna(0)

# %%
df['balls_faced'] = df['balls_faced'].fillna(0)

# %%
# Drop duplicate values

df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 61    False
# 62    False
# 63    False
# 64    False
# 65    False
# Length: 66, dtype: bool

# %%
# change option to show all rows

pd.set_option('display.max_rows',None)

# %%
df[df['Player'].duplicated() == 1]
# Out:
#                 Player       Span  matches_played  Inns  not_outs  Runs  \
# 11      GS Sobers (WI)  1954-1974              93   160        21  8032
# 15      JB Hobbs (ENG)  1908-1930              61   102         7  5410
# 51  V Sehwag (ICC/IND)  2001-2013             104   180         6  8586
# 54       V Kohli (IND)  2011-2024             113   191        11  8848
#
#    highest_inns_score    Ave balls_faced  strike_rate  100  50   0    4s   6s
# 11               365*  57.78       4063+        53.58   26  30  12  593+  32+
# 15                211  56.94       5363+        46.22   15  28   4  276+    8
# 51                319  49.34       10441        82.23   23  32  16  1233   91
# 54               254*  49.15       15924        55.56   29  30  14   991   26

# %%
df[df['Player'].isin(['GS Sobers (WI)','JB Hobbs (ENG)','V Sehwag (ICC/IND)','V Kohli (IND)'])]
# Out:
#                 Player       Span  matches_played  Inns  not_outs  Runs  \
# 10      GS Sobers (WI)  1954-1974              93   160        21  8032
# 11      GS Sobers (WI)  1954-1974              93   160        21  8032
# 14      JB Hobbs (ENG)  1908-1930              61   102         7  5410
# 15      JB Hobbs (ENG)  1908-1930              61   102         7  5410
# 50  V Sehwag (ICC/IND)  2001-2013             104   180         6  8586
# 51  V Sehwag (ICC/IND)  2001-2013             104   180         6  8586
# 53       V Kohli (IND)  2011-2024             113   191        11  8848
# 54       V Kohli (IND)  2011-2024             113   191        11  8848
#
#    highest_inns_score    Ave balls_faced  strike_rate  100  50   0    4s   6s
# 10               365*  57.78       4063+        53.58   26  30  12  593+  32+
# 11               365*  57.78       4063+        53.58   26  30  12  593+  32+
# 14                211  56.94       5363+        46.22   15  28   4  276+    8
# 15                211  56.94       5363+        46.22   15  28   4  276+    8
# 50                319  49.34       10441        82.23   23  32  16  1233   91
# 51                319  49.34       10441        82.23   23  32  16  1233   91
# 53               254*  49.15       15924        55.56   29  30  14   991   26
# 54               254*  49.15       15924        55.56   29  30  14   991   26

# %%
df = df.drop_duplicates()

# %%
df[df['Player'].isin(['GS Sobers (WI)','JB Hobbs (ENG)','V Sehwag (ICC/IND)','V Kohli (IND)'])]
# Out:
#                 Player       Span  matches_played  Inns  not_outs  Runs  \
# 10      GS Sobers (WI)  1954-1974              93   160        21  8032
# 14      JB Hobbs (ENG)  1908-1930              61   102         7  5410
# 50  V Sehwag (ICC/IND)  2001-2013             104   180         6  8586
# 53       V Kohli (IND)  2011-2024             113   191        11  8848
#
#    highest_inns_score    Ave balls_faced  strike_rate  100  50   0    4s   6s
# 10               365*  57.78       4063+        53.58   26  30  12  593+  32+
# 14                211  56.94       5363+        46.22   15  28   4  276+    8
# 50                319  49.34       10441        82.23   23  32  16  1233   91
# 53               254*  49.15       15924        55.56   29  30  14   991   26

# %%
# Split Span into Start and End date

df['Span'].str.split(pat = '-')
# Out:
# 0     [1928, 1948]
# 1     [2022, 2023]
# 2     [2015, 2016]
# 3     [1963, 1970]
# 4     [1930, 1954]
# 5     [1924, 1935]
# 6     [1931, 1939]
# 7     [1955, 1968]
# 8     [1948, 1958]
# 9     [1927, 1947]
# 10    [1954, 1974]
# 12    [2000, 2015]
# 13    [2010, 2024]
# 14    [1908, 1930]
# 16    [1948, 1960]
# 17    [1937, 1955]
# 18    [1995, 2013]
# 19    [1921, 1929]
# 20    [2010, 2024]
# 21    [1968, 1973]
# 22    [1993, 1995]
# 23    [1970, 1984]
# 24    [1935, 1951]
# 25    [1989, 2013]
# 26    [1990, 2006]
# 27    [1976, 1993]
# 28    [1996, 2012]
# 29    [1998, 2010]
# 30    [2000, 2017]
# 31    [1995, 2012]
# 32    [1920, 1929]
# 33    [1992, 2002]
# 34    [2005, 2013]
# 35    [1994, 2015]
# 36    [1971, 1987]
# 37    [1985, 2004]
# 38    [1994, 2009]
# 39    [2004, 2018]
# 40    [1978, 1994]
# 41    [2019, 2024]
# 42    [1974, 1991]
# 43    [1937, 1957]
# 44    [1997, 2014]
# 45    [2012, 2024]
# 46    [1992, 2007]
# 47    [2018, 2024]
# 48    [1948, 1963]
# 49    [1911, 1928]
# 50    [2001, 2013]
# 52    [2019, 2021]
# 53    [2011, 2024]
# 55    [2004, 2015]
# 56    [1961, 1966]
# 57    [1929, 1949]
# 58    [1893, 1905]
# 59    [2001, 2013]
# 60    [1948, 1963]
# 61    [1965, 1981]
# 62    [2002, 2014]
# 63    [1924, 1934]
# 64    [1930, 1938]
# 65    [1928, 1934]
# Name: Span, dtype: object

# %%
df['Start_year'] = df['Span'].str.split(pat = '-').str[0]
df['end_year'] = df['Span'].str.split(pat = '-').str[1]

df
# Out:
#                       Player       Span  matches_played  Inns  not_outs  \
# 0           DG Bradman (AUS)  1928-1948              52    80        10
# 1             HC Brook (ENG)  2022-2023              12    20         1
# 2             AC Voges (AUS)  2015-2016              20    31         7
# 3            RG Pollock (SA)  1963-1970              23    41         4
# 4            GA Headley (WI)  1930-1954              22    40         4
# 5          H Sutcliffe (ENG)  1924-1935              54    84         9
# 6            E Paynter (ENG)  1931-1939              20    31         5
# 7        KF Barrington (ENG)  1955-1968              82   131        15
# 8             ED Weekes (WI)  1948-1958              48    81         5
# 9           WR Hammond (ENG)  1927-1947              85   140        16
# 10            GS Sobers (WI)  1954-1974              93   160        21
# 12        KC Sangakkara (SL)  2000-2015             134   233        17
# 13           SPD Smith (AUS)  2010-2024             109   195        25
# 14            JB Hobbs (ENG)  1908-1930              61   102         7
# 16           CL Walcott (WI)  1948-1960              44    74         7
# 17            L Hutton (ENG)  1937-1955              79   138        15
# 18        JH Kallis (ICC/SA)  1995-2013             166   280        40
# 19        GE Tyldesley (ENG)  1921-1929              14    20         2
# 20        KS Williamson (NZ)  2010-2024             100   176        17
# 21             CA Davis (WI)  1968-1973              15    29         5
# 22           VG Kambli (IND)  1993-1995              17    21         1
# 23         GS Chappell (AUS)  1970-1984              87   151        19
# 24            AD Nourse (SA)  1935-1951              34    62         7
# 25        SR Tendulkar (IND)  1989-2013             200   329        33
# 24   115+    6       1935     1951
# 25  2058+   69       1989     2013
# 26   1559   88       1990     2006
# 27   788+   48       1976     1993
# 28   1654   21       1996     2012
# 29    957   51       1998     2010
# 30   1082   70       2000     2017
# 31   1509   73       1995     2012
# 32   102+    3       1920     1929
# 33    543   20       1992     2002
# 34    685   39       2005     2013
# 35   1285   36       1994     2015
# 36   908+   26       1971     1987
# 37   1175   20       1985     2004
# 38   1049   82       1994     2009
# 39   1024   64       2004     2018
# 40   1161   28       1978     1994
# 41    158   29       2019     2024
# 42   952+   84       1974     1991
# 43   342+    3       1937     1957
# 44   1387   61       1997     2014
# 45   1280   44       2012     2024
# 46   1105   48       1992     2007
# 47    463   12       2018     2024
# 48   240+   11       1948     1963
# 49    38+    0       1911     1928
# 50   1233   91       2001     2013
# 52    148    5       2019     2021
# 53    991   26       2011     2024
# 55    978   39       2004     2015
# 56   123+   20       1961     1966
# 57    41+    1       1929     1949
# 58    51+    0       1893     1905
# 59    633    7       2001     2013
# 60   427+    1       1948     1963
# 61   525+   23       1965     1981
# 62   1165   24       2002     2014
# 63   119+    0       1924     1934
# 64   241+   5+       1930     1938
# 65    53+    0       1928     1934

# %%
# drop span col

df = df.drop(['Span'], axis=1)

# %%
# SPlit the country from the player

df['Player'].str.split(pat = '(')
# Out:
# 0             [DG Bradman , AUS)]
# 1               [HC Brook , ENG)]
# 2               [AC Voges , AUS)]
# 3              [RG Pollock , SA)]
# 4              [GA Headley , WI)]
# 5            [H Sutcliffe , ENG)]
# 6              [E Paynter , ENG)]
# 7          [KF Barrington , ENG)]
# 8               [ED Weekes , WI)]
# 9             [WR Hammond , ENG)]
# 10              [GS Sobers , WI)]
# 12          [KC Sangakkara , SL)]
# 13             [SPD Smith , AUS)]
# 14              [JB Hobbs , ENG)]
# 16             [CL Walcott , WI)]
# 17              [L Hutton , ENG)]
# 18          [JH Kallis , ICC/SA)]
# 19          [GE Tyldesley , ENG)]
# 20          [KS Williamson , NZ)]
# 21               [CA Davis , WI)]
# 22             [VG Kambli , IND)]
# 23           [GS Chappell , AUS)]
# 24              [AD Nourse , SA)]
# 25          [SR Tendulkar , IND)]
# 26            [BC Lara , ICC/WI)]
# 27         [Javed Miandad , PAK)]
# 28          [R Dravid , ICC/IND)]
# 29       [Mohammad Yousuf , PAK)]
# 30           [Younis Khan , PAK)]
# 31            [RT Ponting , AUS)]
# 32               [J Ryder , AUS)]
# 33              [A Flower , ZIM)]
# 34            [MEK Hussey , AUS)]
# 35          [S Chanderpaul , WI)]
# 36           [SM Gavaskar , IND)]
# 37              [SR Waugh , AUS)]
# 38             [ML Hayden , AUS)]
# 39         [AB de Villiers , SA)]
# 40             [AR Border , AUS)]
# 41            [DJ Mitchell , NZ)]
# 42           [IVA Richards , WI)]
# 43           [DCS Compton , ENG)]
# 44       [DPMD Jayawardene , SL)]
# 45               [JE Root , ENG)]
# 46    [Inzamam-ul-Haq , ICC/PAK)]
# 47         [M Labuschagne , AUS)]
# 48            [FMM Worrell , WI)]
# 49               [CP Mead , ENG)]
# 50          [V Sehwag , ICC/IND)]
# 52              [Abid Ali , PAK)]
# 53               [V Kohli , IND)]
# 55             [MJ Clarke , AUS)]
# 56               [KC Bland , SA)]
# 57             [B Mitchell , SA)]
# 58        [Hon.FS Jackson , ENG)]
# 59         [TT Samaraweera , SL)]
# 60             [RN Harvey , AUS)]
# 61            [KD Walters , AUS)]
# 62           [GC Smith , ICC/SA)]
# 63           [WH Ponsford , AUS)]
# 64             [SJ McCabe , AUS)]
# 65            [DR Jardine , ENG)]
# Name: Player, dtype: object

# %%
df['Country'] = df['Player'].str.split(pat = '(').str[1]

# %%
df['Country'] = df['Country'].str.split(pat = ')').str[0]

# %%
df['Player'] =  df['Player'].str.split(pat = '(').str[0]

df['Player']
# Out:
# 0           DG Bradman
# 1             HC Brook
# 2             AC Voges
# 3           RG Pollock
# 4           GA Headley
# 5          H Sutcliffe
# 6            E Paynter
# 7        KF Barrington
# 8            ED Weekes
# 9           WR Hammond
# 10           GS Sobers
# 12       KC Sangakkara
# 13           SPD Smith
# 14            JB Hobbs
# 16          CL Walcott
# 17            L Hutton
# 18           JH Kallis
# 19        GE Tyldesley
# 20       KS Williamson
# 21            CA Davis
# 22           VG Kambli
# 23         GS Chappell
# 24           AD Nourse
# 25        SR Tendulkar
# 26             BC Lara
# 27       Javed Miandad
# 28            R Dravid
# 29     Mohammad Yousuf
# 30         Younis Khan
# 31          RT Ponting
# 32             J Ryder
# 33            A Flower
# 34          MEK Hussey
# 35       S Chanderpaul
# 36         SM Gavaskar
# 37            SR Waugh
# 38           ML Hayden
# 39      AB de Villiers
# 40           AR Border
# 41         DJ Mitchell
# 42        IVA Richards
# 43         DCS Compton
# 44    DPMD Jayawardene
# 45             JE Root
# 46      Inzamam-ul-Haq
# 47       M Labuschagne
# 48         FMM Worrell
# 49             CP Mead
# 50            V Sehwag
# 52            Abid Ali
# 53             V Kohli
# 55           MJ Clarke
# 56            KC Bland
# 57          B Mitchell
# 58      Hon.FS Jackson
# 59      TT Samaraweera
# 60           RN Harvey
# 61          KD Walters
# 62            GC Smith
# 63         WH Ponsford
# 64           SJ McCabe
# 65          DR Jardine
# Name: Player, dtype: object

# %%
# remove */+ from cols

df['highest_inns_score'] = df['highest_inns_score'].str.split(pat = '*').str[0]

# %%
df['balls_faced'] = df['balls_faced'].str.split(pat = '+').str[0]
df['4s'] = df['4s'].str.split(pat = '+').str[0]
df['6s'] = df['6s'].str.split(pat = '+').str[0]

# %%
# change data types

df.dtypes
# Out:
# Player                 object
# matches_played          int64
# Inns                    int64
# not_outs                int64
# Runs                    int64
# highest_inns_score     object
# Ave                   float64
# balls_faced            object
# strike_rate           float64
# 100                     int64
# 50                      int64
# 0                       int64
# 4s                     object
# 6s                     object
# Start_year             object
# end_year               object
# Country                object
# dtype: object

# %%
# set numeric cols as int

df =  df.astype({'highest_inns_score':'int','Start_year':'int','end_year':'int','4s': 'int','6s':'int','balls_faced': 'int'})
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[25], line 3
#       1 # set numeric cols as int
# ----> 3 df =  df.astype({'highest_inns_score':'int','Start_year':'int','end_year':'int','4s': 'int','6s':'int','balls_faced': 'int'})
#
# File F:\Anaconda\Lib\site-packages\pandas\core\generic.py:6513, in NDFrame.astype(self, dtype, copy, errors)
#    6511 else:
#    6512     try:
# -> 6513         res_col = col.astype(dtype=cdt, copy=copy, errors=errors)
#    6514     except ValueError as ex:
#    6515         ex.args = (
#    6516             f"{ex}: Error while type casting for column '{col_name}'",
#    6517         )
#
# File F:\Anaconda\Lib\site-packages\pandas\core\generic.py:6534, in NDFrame.astype(self, dtype, copy, errors)
#    6530     results = [ser.astype(dtype, copy=copy) for _, ser in self.items()]
#    6532 else:
#    6533     # else, only a single dtype is given
# -> 6534     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6535     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6536     return res.__finalize__(self, method="astype")
#
# File F:\Anaconda\Lib\site-packages\pandas\core\internals\managers.py:414, in BaseBlockManager.astype(self, dtype, copy, errors)
#     411 elif using_copy_on_write():
#     412     copy = False
# --> 414 return self.apply(
#     415     "astype",
#     416     dtype=dtype,
#     417     copy=copy,
#     418     errors=errors,
#     419     using_cow=using_copy_on_write(),
#     420 )
#
# File F:\Anaconda\Lib\site-packages\pandas\core\internals\managers.py:354, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     352         applied = b.apply(f, **kwargs)
#     353     else:
# --> 354         applied = getattr(b, f)(**kwargs)
#     355     result_blocks = extend_blocks(applied, result_blocks)
#     357 out = type(self).from_blocks(result_blocks, self.axes)
#
# File F:\Anaconda\Lib\site-packages\pandas\core\internals\blocks.py:616, in Block.astype(self, dtype, copy, errors, using_cow)
#     596 """
#     597 Coerce to the new dtype.
#     598
#    (...)
#     612 Block
#     613 """
#     614 values = self.values
# --> 616 new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     618 new_values = maybe_coerce_values(new_values)
#     620 refs = None
#
# File F:\Anaconda\Lib\site-packages\pandas\core\dtypes\astype.py:238, in astype_array_safe(values, dtype, copy, errors)
#     235     dtype = dtype.numpy_dtype
#     237 try:
# --> 238     new_values = astype_array(values, dtype, copy=copy)
#     239 except (ValueError, TypeError):
#     240     # e.g. _astype_nansafe can fail on object-dtype of strings
#     241     #  trying to convert to float
#     242     if errors == "ignore":
#
# File F:\Anaconda\Lib\site-packages\pandas\core\dtypes\astype.py:183, in astype_array(values, dtype, copy)
#     180     values = values.astype(dtype, copy=copy)
#     182 else:
# --> 183     values = _astype_nansafe(values, dtype, copy=copy)
#     185 # in pandas we don't store numpy str dtypes, so convert to object
#     186 if isinstance(dtype, np.dtype) and issubclass(values.dtype.type, str):
#
# File F:\Anaconda\Lib\site-packages\pandas\core\dtypes\astype.py:134, in _astype_nansafe(arr, dtype, copy, skipna)
#     130     raise ValueError(msg)
#     132 if copy or arr.dtype == object or dtype == object:
#     133     # Explicit copy, or required since NumPy can't view from / to object.
# --> 134     return arr.astype(dtype, copy=True)
#     136 return arr.astype(dtype, copy=copy)
#
# ValueError: cannot convert float NaN to integer: Error while type casting for column 'balls_faced'

# %%
## When we removed the */+ from cols, NaN was introduced in 'balls_faced' as it was previously 0 and we did string split

# %%
df['balls_faced'] = df['balls_faced'].fillna(0)

# %%
df =  df.astype({'highest_inns_score':'int','Start_year':'int','end_year':'int','4s': 'int','6s':'int','balls_faced': 'int'})

# %%
df.dtypes
# Out:
# Player                 object
# matches_played          int64
# Inns                    int64
# not_outs                int64
# Runs                    int64
# highest_inns_score      int32
# Ave                   float64
# balls_faced             int32
# strike_rate           float64
# 100                     int64
# 50                      int64
# 0                       int64
# 4s                      int32
# 6s                      int32
# Start_year              int32
# end_year                int32
# Country                object
# dtype: object

# %%
# Build out career length column

df['career_length'] = df['end_year'] - df['Start_year']

# %%
df
# Out:
#                Player  matches_played  Inns  not_outs   Runs  \
# 0         DG Bradman               52    80        10   6996
# 1           HC Brook               12    20         1   1181
# 2           AC Voges               20    31         7   1485
# 14   8        1908      1930      ENG             22
# 16  11        1948      1960       WI             12
# 17   7        1937      1955      ENG             18
# 18  97        1995      2013   ICC/SA             18
# 19   2        1921      1929      ENG              8
# 20  24        2010      2024       NZ             14
# 21   1        1968      1973       WI              5
# 22   6        1993      1995      IND              2
# 23  16        1970      1984      AUS             14
# 24   6        1935      1951       SA             16
# 25  69        1989      2013      IND             24
# 26  88        1990      2006   ICC/WI             16
# 27  48        1976      1993      PAK             17
# 28  21        1996      2012  ICC/IND             16
# 29  51        1998      2010      PAK             12
# 30  70        2000      2017      PAK             17
# 31  73        1995      2012      AUS             17
# 32   3        1920      1929      AUS              9
# 33  20        1992      2002      ZIM             10
# 34  39        2005      2013      AUS              8
# 35  36        1994      2015       WI             21
# 36  26        1971      1987      IND             16
# 37  20        1985      2004      AUS             19
# 38  82        1994      2009      AUS             15
# 39  64        2004      2018       SA             14
# 40  28        1978      1994      AUS             16
# 41  29        2019      2024       NZ              5
# 42  84        1974      1991       WI             17
# 43   3        1937      1957      ENG             20
# 44  61        1997      2014       SL             17
# 45  44        2012      2024      ENG             12
# 46  48        1992      2007  ICC/PAK             15
# 47  12        2018      2024      AUS              6
# 48  11        1948      1963       WI             15
# 49   0        1911      1928      ENG             17
# 50  91        2001      2013  ICC/IND             12
# 52   5        2019      2021      PAK              2
# 53  26        2011      2024      IND             13
# 55  39        2004      2015      AUS             11
# 56  20        1961      1966       SA              5
# 57   1        1929      1949       SA             20
# 58   0        1893      1905      ENG             12
# 59   7        2001      2013       SL             12
# 60   1        1948      1963      AUS             15
# 61  23        1965      1981      AUS             16
# 62  24        2002      2014   ICC/SA             12
# 63   0        1924      1934      AUS             10
# 64   5        1930      1938      AUS              8
# 65   0        1928      1934      ENG              6

# %%
# Q1: What is the average career length?

df['career_length'].mean()
# Out:
# 13.193548387096774

# %%
# Q2: Average Strike rate of cricketers who's career length > 10yrs

df[df['career_length'] > 10]['strike_rate'].mean()
# Out:
# 47.94681818181819

# %%
# Q3: Find number of cricketers who played before 1960

df[df['Start_year'] < 1960]['Player'].count()
# Out:
# 23

# %%
# Q4: Max highest innings by country

df.groupby('Country')['highest_inns_score'].max()
# Out:
# Country
# AUS        380
# ENG        364
# ICC/IND    319
# ICC/PAK    329
# ICC/SA     277
# ICC/WI     400
# IND        254
# NZ         251
# PAK        313
# SA         278
# SL         374
# WI         365
# ZIM        232
# Name: highest_inns_score, dtype: int32

# %%
# Q5: Hundreds, fifties and ducks avg by country

df.groupby('Country')[['100','50','0']].mean()
# Out:
#                100         50          0
# Country
# AUS      20.625000  28.375000   8.562500
# ENG      12.384615  20.846154   4.307692
# ICC/IND  29.500000  47.500000  12.000000
# ICC/PAK  25.000000  46.000000  15.000000
# ICC/SA   36.000000  48.000000  13.500000
# ICC/WI   34.000000  48.000000  17.000000
# IND      29.500000  36.500000  10.750000
# NZ       18.500000  22.000000   6.000000
# PAK      21.250000  28.000000   9.500000
# SA        9.800000  20.200000   3.400000
# SL       28.666667  44.000000  12.333333
# WI       16.625000  25.625000   7.250000
# ZIM      12.000000  27.000000   5.000000
